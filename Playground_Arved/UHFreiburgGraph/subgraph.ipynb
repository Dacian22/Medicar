# %%
from submap import Submap

# %%
# define parameters for the subgraph
subgraph_params = {
                'special_nodes': ['Zwischen den Räumen', 'Stimme vom Berg',
                                'Emmaus Kapelle', 'Klinik für Frauenheilkunde [1]',
                                'Ernst von Bergmann'],
                'allowed_highway_types': ['footway', 'service']
}

# define parameters for the shortest path
shortest_path_params = {
                'start_node': 'Zwischen den Räumen',
                'end_node': 'Ernst von Bergmann'
}

# %%
# create the submap
submap = Submap(**subgraph_params)
# determine closest nodes to the special nodes
closest_nodes = submap.closest_node_to_special_nodes()
# create the subgraph
subgraph = submap.create_graph()
# reduce the subgraph to the largest connected component
subgraph = submap.keep_largest_connected_component(subgraph)
# label edges of the graph
edge_labels = submap.label_edges(subgraph)
# calculate the shortest path
shortest_path = submap.find_astar_path(subgraph, **shortest_path_params)

# %%
# plot the graph
submap.plot_graph(subgraph, edge_labels)

# %%
submap.translate_path_to_mqtt(shortest_path)
# Out:
# [{'edgeId': 'edge_7112443020_7047823177',
#   'sequenceId': 0,
#   'startNodeId': '7112443020',
#   'endNodeId': '7047823177'},
#  {'edgeId': 'edge_7047823177_7047823178',
#   'sequenceId': 1,
#   'startNodeId': '7047823177',
#   'endNodeId': '7047823178'},
#  {'edgeId': 'edge_7047823178_10163996199',
#   'sequenceId': 2,
#   'startNodeId': '7047823178',
#   'endNodeId': '10163996199'},
#  {'edgeId': 'edge_10163996199_2127917103',
#   'sequenceId': 3,
#   'startNodeId': '10163996199',
#   'endNodeId': '2127917103'},
#  {'edgeId': 'edge_2127917103_245411466',
#   'sequenceId': 4,
#   'startNodeId': '2127917103',
#   'endNodeId': '245411466'},
#  {'edgeId': 'edge_245411466_245411467',
#   'sequenceId': 5,
#   'startNodeId': '245411466',
#   'endNodeId': '245411467'},
#  {'edgeId': 'edge_245411467_245411468',
#   'sequenceId': 6,
#   'startNodeId': '245411467',
#   'endNodeId': '245411468'},
#  {'edgeId': 'edge_245411468_245411469',
#   'sequenceId': 7,
#   'startNodeId': '245411468',
#   'endNodeId': '245411469'},
#  {'edgeId': 'edge_245411469_8214388994',
#   'sequenceId': 8,
#   'startNodeId': '245411469',
#   'endNodeId': '8214388994'},
#  {'edgeId': 'edge_8214388994_8214469912',
#   'sequenceId': 9,
#   'startNodeId': '8214388994',
#   'endNodeId': '8214469912'},
#  {'edgeId': 'edge_8214469912_245411470',
#   'sequenceId': 10,
#   'startNodeId': '8214469912',
#   'endNodeId': '245411470'},
#  {'edgeId': 'edge_245411470_6820696987',
#   'sequenceId': 11,
#   'startNodeId': '245411470',
#   'endNodeId': '6820696987'},
#  {'edgeId': 'edge_6820696987_245411471',
#   'sequenceId': 12,
#   'startNodeId': '6820696987',
#   'endNodeId': '245411471'},
#  {'edgeId': 'edge_245411471_9622545346',
#   'sequenceId': 13,
#   'startNodeId': '245411471',
#   'endNodeId': '9622545346'}]
